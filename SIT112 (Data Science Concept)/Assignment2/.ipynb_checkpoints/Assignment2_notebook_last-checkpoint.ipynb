# %% [markdown]
# # <span style="color:#0b486b">SIT 112 - Data Science Concepts - Assignment 2</span>
#
# ---
# Lecturer: Sergiy Shelyag | sergiy.shelyag@deakin.edu.au<br />
#
# School of Information Technology, <br />
# Deakin University, VIC, Australia.
#
# ### <span style="color:#0b486b">Due: 5pm, 22th May 2020 </span>
# ---

# %% [markdown]
# ## <span style="color:#0b486b">Instructions</span>
#
# This notebook has been prepared for you to complete Assignment 2. Some sections have been partially completed  to help you get started. **The total marks for this notebook is 200**.
#
# * Before you start, read the entire notebook carefully to understand what you need to do. You should also refer to the main instructions in *Assignment2_instructions.pdf*  to know what else you need to complete for this assignment as well submission instruction. <br><br>
#
# * Instructions marked with **(D)** and **(HD)** are for students aiming at high grades. They are more involved and can be completed after all other instructions.
#
#
# * For each cell marked with **#YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL**, there will be places where you **must** supply your own codes when instructed. <br><br>
#
# * For each cell marked with **#YOU ARE REQUIRED TO INSERT YOUR COMMENT IN THIS CELL**, there will be place where you **must** provide your own comment when instructed. <br><br>
#
#
# ### Submission
#
# You are required to submit **five** files: <br><br>
#
# * The source of your solution notebook: **[groupID]_assignment2_solution.ipynb**
# * An exported version of your output: **[groupID]_assignment2_output.html**
# * Three json data files storing tweets collected for the three keywords, named **[groupID]_[w1].json**, **[groupID]_[w2].json**, **[groupID]_[w3].json** where **[w1], [w2], [w3]** are the three keywords you have been provided.
#
#
#
# As you go through this notebook:
#
# * markdown cells marked with **Note** mean description sections.
# * markdown cells marked with **Instruction** mean the instructions given to you to complete the designated section.

# %% [markdown]
# ## <span style="color:#0b486b">Part 1: Crawling and Storing Tweet Data</span>
#
#
# The first part of the assignment examines your skills and knowledge to query tweets and store them in json files. For **each** provided keyword, your tasks are:
#
# * Crawl all tweets which contain this keyword written in English and geocoded within the location, provided for your group.
# * Store the tweets collected into json files.
#
# ***Follow the instructions below to complete your task***.

# %% [markdown]
# **Note**: The following packages will be required for this assignment. If you need to import more packages, you might append them to the end of the following cell.

# %%
#Import packages needed for processing
import re
import json
import xml
import numpy as np
from collections import Counter
from TwitterAPI import TwitterAPI # in case you need to install this package, see practical 6
from sklearn.cluster import KMeans

import requests

# disabling urllib3 warnings
requests.packages.urllib3.disable_warnings()

import matplotlib.pyplot as plt
# %matplotlib inline

#If you need add any additional packages, then add them below
import sklearn as sklearn

# %% [markdown]
# **Instruction 1.1**. Enter your provided keywords to the variable **keywords** below.
#
# [**Total mark: 3**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

#Enter the list of three keywords you selected to the variables keywords below
#e.g. keywords = ["abc", "def", "ghi"]

keywords =["pizza", "politics", "raccoon"]  # INSERT YOUR CODE

# %% [markdown]
# **Instruction 1.2**. Before you can perform a query to Twitter API, you need to supply authentication information. Practical sessions 6 and 7 show you how to obtain this information. **Your task is to supply the authentication information in the cell below**.
#
# **Note**: You might decide to regenerate this authentication from the pracs if you would like too. <span style="color:red">After the assignment has been marked, you are strongly recommended to regenerate this authentication information from your account to maintain your privacy.</span>
#
#
# [**Total mark: 5**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

# Twitter API credentials 
CONSUMER_KEY = "QQKr5UEQnrFgGsuU50JIswEsh"
CONSUMER_SECRET =  "GlqpYQJ9Al46xeqHTjRIGThT0vVHDXxrT9R6xeqANaT2fkuUUM"
OAUTH_TOKEN =  "115285332-g54VHuXZH62S6BFLVZJxkGhiufWh2Vohwk9YBLom"
OAUTH_TOKEN_SECRET =  "HktGxXXUCgF87tL8KXnrCcnjIjGa4D55yCA7OwU1iVaP8"

# Authonticating with your application credentials
api = TwitterAPI(CONSUMER_KEY,
                 CONSUMER_SECRET,
                 OAUTH_TOKEN,
                 OAUTH_TOKEN_SECRET) #INSERT YOUR CODE HERE

# %% [markdown]
# **Note**: As you have learned from the pracical sessions, to perform a query from Twitter API for a particular geo-coded location you need a center point and a radius. The center point is specified by its (latitude,longitute) pair. **The information below has been provided to you to perform the query in the subsequent tasks**.

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
# geo coordinations of the desired place
PLACE_LAT = -37.806943 
PLACE_LON = 144.981997
PLACE_RAD = 10

# %% [markdown]
# **Instruction 1.3**. For each keyword, you are required to crawl at least **200** tweets (the more the better) using the Twitter API. However, as you have learned from the practical sessions, each query will return a maximum of only **100** tweets. Therefore, subsequent query **must** use the maximum Tweet ID from the previous batch to crawl the next lot.
#
# The following function, called ***retrieve_tweets()***, has been **partially** implemented to automatically download tweets until it reaches the maximum number of tweets needed.
#
# For example, a function call
# ```
# retrieve_tweets(api, 'car', 50, 200, latitude, longitude, radius)
# ```
# will attempt to crawl a total of at least 200 tweets that contains the word 'car' for a location with given latitude, longidude and radius around it. Within each single query, it will attempt to obtain 50 tweets.
#
# **Your task is to walk through this function and enter your own codes where instructed to complete the function**.
#
# [**Total mark: 10**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
You will be required to insert your own codes to complete this function. 
Walk through this function and enter your own codes where instructed.
'''
def retrieve_tweets(api, keyword, batch_count, total_count, latitude, longitude, radius):
    """
    collects tweets using the Twitter search API
    
    api:         Twitter API instance
    keyword:     search keyword
    batch_count: maximum number of tweets to collect per each request
    total_count: maximum number of tweets in total
    """

    
    # the collection of tweets to be returned
    tweets_unfiltered = []
    tweets = []
    
    # the number of tweets within a single query
    batch_count = str(batch_count)
    
    '''
    You are required to insert your own code where instructed to perform the first query to Twitter API.
    Hint: revise the practical session on Twitter API on how to perform query to Twitter API.
    '''
    # per the first query, to obtain max_id_str which will be used later to query sub
    resp = api.request('search/tweets', {'q': keyword,
                                         'count': batch_count,
                                         'lang':'en',
                                         'result_type':'recent',
                                         'geocode':'{},{},{}mi'.format(latitude, longitude, radius)})
    
    # store the tweets in a list

    # check first if there was an error
    if ('errors' in resp.json()):
        errors = resp.json()['errors']
        if (errors[0]['code'] == 88):
            print('Too many attempts to load tweets.')
            print('You need to wait for a few minutes before accessing Twitter API again.')
    
    if ('statuses' in resp.json()):
        tweets_unfiltered += resp.json()['statuses']
        tweets = [tweet for tweet in tweets_unfiltered if ((tweet['retweeted'] != True) and ('RT @' not in tweet['text']))]
    
        # find the max_id_str for the next batch
        ids = [tweet['id'] for tweet in tweets_unfiltered]
        max_id_str = str(min(ids))

        # loop until as many tweets as total_count is collected
        number_of_tweets = len(tweets)
        while number_of_tweets < total_count:

            resp = api.request('search/tweets', {'q': keyword,
                                             'count': batch_count,
                                             'lang':'en',
                                             'result_type':'recent',
                                             'max_id': max_id_str,
                                             'geocode': '{},{},{}mi'.format(latitude, longitude, radius)}
                          )

            if ('statuses' in resp.json()):
                tweets_unfiltered += resp.json()['statuses']
                tweets = [tweet for tweet in tweets_unfiltered if ((tweet['retweeted'] != True) and ('RT @' not in tweet['text']))]
 
                ids = [tweet['id'] for tweet in tweets_unfiltered]
                max_id_str = str(min(ids))
            
                number_of_tweets = len(tweets)
        
            print("{} tweets are collected for keyword {}. Last tweet created at {}".format(number_of_tweets, 
                                                                                    keyword, 
                                                                                    tweets[number_of_tweets-1]['created_at']))
    return tweets

# %% [markdown]
# **Instruction 1.4**. After having defined the ***retrieve_tweets()*** function above, you are now ready to use this function to collect your tweets. Your task is to write the code to perform three function calls, each of which corresponds to one keyword. And, you are required to collect at least **200** tweets for each keyword (the more the better).
#
# [**Total mark: 9**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Your task is to write the code to perform three function calls, each corresponds to one keyword. 
And, you are required to collect at least 200 tweets for each key word.
'''

# Collecting the tweets for three assigned keywords, 
# Your function call should look like this:  retrieve_tweets(api,'keyword',single_count,total_count)

k1_tweets = retrieve_tweets(api,keywords[0],50,200, PLACE_LAT, PLACE_LON, PLACE_RAD)
k2_tweets = retrieve_tweets(api,keywords[1],50,200, PLACE_LAT, PLACE_LON, PLACE_RAD)
k3_tweets = retrieve_tweets(api,keywords[2],50,200, PLACE_LAT, PLACE_LON, PLACE_RAD)

# PLEASE NOTE THAT IF YOU RUN THIS CELL, IT MIGHT TAKE A WHILE TO DOWNLOAD ALL THE TWEETS REQUIRED.
# MAKE SURE THAT YOU WAIT UNTILL THE CELL FINISHES RUNNING.
# Out:
# 80 tweets are collected for keyword pizza. Last tweet created at Mon May 18 22:55:03 +0000 2020
# 119 tweets are collected for keyword pizza. Last tweet created at Mon May 18 01:05:41 +0000 2020
# 137 tweets are collected for keyword pizza. Last tweet created at Sun May 17 11:38:23 +0000 2020
# 162 tweets are collected for keyword pizza. Last tweet created at Sun May 17 04:36:54 +0000 2020
# 210 tweets are collected for keyword pizza. Last tweet created at Sat May 16 05:11:09 +0000 2020
# 16 tweets are collected for keyword politics. Last tweet created at Wed May 20 06:31:34 +0000 2020
# 26 tweets are collected for keyword politics. Last tweet created at Wed May 20 05:11:17 +0000 2020
# 34 tweets are collected for keyword politics. Last tweet created at Wed May 20 04:31:29 +0000 2020
# 39 tweets are collected for keyword politics. Last tweet created at Wed May 20 03:31:02 +0000 2020
# 49 tweets are collected for keyword politics. Last tweet created at Wed May 20 02:49:18 +0000 2020
# 61 tweets are collected for keyword politics. Last tweet created at Wed May 20 02:22:26 +0000 2020
# 74 tweets are collected for keyword politics. Last tweet created at Wed May 20 01:49:05 +0000 2020
# 83 tweets are collected for keyword politics. Last tweet created at Wed May 20 01:13:24 +0000 2020
# 93 tweets are collected for keyword politics. Last tweet created at Wed May 20 00:50:06 +0000 2020
# 108 tweets are collected for keyword politics. Last tweet created at Wed May 20 00:00:54 +0000 2020
# 117 tweets are collected for keyword politics. Last tweet created at Tue May 19 23:25:55 +0000 2020
# 132 tweets are collected for keyword politics. Last tweet created at Tue May 19 22:40:59 +0000 2020
# 142 tweets are collected for keyword politics. Last tweet created at Tue May 19 21:48:16 +0000 2020
# 154 tweets are collected for keyword politics. Last tweet created at Tue May 19 19:57:22 +0000 2020
# 161 tweets are collected for keyword politics. Last tweet created at Tue May 19 15:47:58 +0000 2020
# 177 tweets are collected for keyword politics. Last tweet created at Tue May 19 13:21:27 +0000 2020
# 193 tweets are collected for keyword politics. Last tweet created at Tue May 19 12:25:31 +0000 2020
# 208 tweets are collected for keyword politics. Last tweet created at Tue May 19 11:58:17 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# ...
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# 16 tweets are collected for keyword raccoon. Last tweet created at Mon May 11 23:12:39 +0000 2020
# WARNING:root:<class 'requests.exceptions.ConnectTimeout'> HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/search/tweets.json?q=raccoon&count=50&lang=en&result_type=recent&max_id=1259953502702366720&geocode=-37.806943%2C144.981997%2C10mi (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x000001A21BE90320>, 'Connection to api.twitter.com timed out. (connect timeout=5)'))
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# c:\python368\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# c:\python368\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# c:\python368\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# c:\python368\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# c:\python368\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#
# c:\python368\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#
# c:\python368\lib\site-packages\urllib3\connection.py in connect(self)
#     299         # Add certificate verification
# --> 300         conn = self._new_conn()
#     301         hostname = self.host
#
# c:\python368\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     163                 "Connection to %s timed out. (connect timeout=%s)"
# --> 164                 % (self.host, self.timeout),
#     165             )
#
# ConnectTimeoutError: (<urllib3.connection.VerifiedHTTPSConnection object at 0x000001A21BE90320>, 'Connection to api.twitter.com timed out. (connect timeout=5)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\python368\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# c:\python368\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# c:\python368\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     435         if new_retry.is_exhausted():
# --> 436             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     437
#
# MaxRetryError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/search/tweets.json?q=raccoon&count=50&lang=en&result_type=recent&max_id=1259953502702366720&geocode=-37.806943%2C144.981997%2C10mi (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x000001A21BE90320>, 'Connection to api.twitter.com timed out. (connect timeout=5)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# c:\python368\lib\site-packages\TwitterAPI\TwitterAPI.py in request(self, resource, params, files, method_override)
#     169                         files=files,
# --> 170                         proxies=self.proxies)
#     171             except (ConnectionError, ProtocolError, ReadTimeout, ReadTimeoutError,
#
# c:\python368\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#
# c:\python368\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#
# c:\python368\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     503                 if not isinstance(e.reason, NewConnectionError):
# --> 504                     raise ConnectTimeout(e, request=request)
#     505
#
# ConnectTimeout: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/search/tweets.json?q=raccoon&count=50&lang=en&result_type=recent&max_id=1259953502702366720&geocode=-37.806943%2C144.981997%2C10mi (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x000001A21BE90320>, 'Connection to api.twitter.com timed out. (connect timeout=5)'))
#
# During handling of the above exception, another exception occurred:
#
# TwitterConnectionError                    Traceback (most recent call last)
# <ipython-input-36-f7c72f884632> in <module>
#      10 k1_tweets = retrieve_tweets(api,keywords[0],50,200, PLACE_LAT, PLACE_LON, PLACE_RAD)
#      11 k2_tweets = retrieve_tweets(api,keywords[1],50,200, PLACE_LAT, PLACE_LON, PLACE_RAD)
# ---> 12 k3_tweets = retrieve_tweets(api,keywords[2],50,200, PLACE_LAT, PLACE_LON, PLACE_RAD)
#      13
#      14 # PLEASE NOTE THAT IF YOU RUN THIS CELL, IT MIGHT TAKE A WHILE TO DOWNLOAD ALL THE TWEETS REQUIRED.
#
# <ipython-input-35-fb2c4b445cfd> in retrieve_tweets(api, keyword, batch_count, total_count, latitude, longitude, radius)
#      59                                              'result_type':'recent',
#      60                                              'max_id': max_id_str,
# ---> 61                                              'geocode': '{},{},{}mi'.format(latitude, longitude, radius)}
#      62                           )
#      63
#
# c:\python368\lib\site-packages\TwitterAPI\TwitterAPI.py in request(self, resource, params, files, method_override)
#     171             except (ConnectionError, ProtocolError, ReadTimeout, ReadTimeoutError,
#     172                     SSLError, ssl.SSLError, socket.error) as e:
# --> 173                 raise TwitterConnectionError(e)
#     174             return TwitterResponse(r, session.stream)
#     175
#
# TwitterConnectionError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/search/tweets.json?q=raccoon&count=50&lang=en&result_type=recent&max_id=1259953502702366720&geocode=-37.806943%2C144.981997%2C10mi (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x000001A21BE90320>, 'Connection to api.twitter.com timed out. (connect timeout=5)'))

# %% [markdown]
# **Instruction 1.5**. To verify the downloading process, write your code to print out the number of tweets which has been collected for each keyword.
#
# [**Total mark: 3**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your code to print the number of tweets have been collected for each keyword
'''
# INSERT YOUR CODE HERE
def get_tweets_count(keyword ,tweets): 
    print("keyword :"+keyword+"  collected "+str(len(tweets))+" tweets")


get_tweets_count(keywords[0],k1_tweets)
get_tweets_count(keywords[1],k2_tweets)
get_tweets_count(keywords[2],k3_tweets)
# Out:
# keyword :pizza  collected 210 tweets
# keyword :politics  collected 208 tweets
# keyword :raccoon  collected 200 tweets

# %% [markdown]
# **Note:** Each tweet is stored in a dictionary where its keywords are fields in the tweet and values are the information of the fields. The cell below print the type of a tweet.

# %%
# Data type of tweets
print(type(k1_tweets[0]))
# Out:
# <class 'dict'>

# %% [markdown]
# **Instruction 1.6**.  To examine what the tweets look like, in the cell below write your code to print out all fields of the first tweet in `k1_tweets` and print out the text of the first tweet collected for each keyword.
#
# [**Total mark: 6**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your code to print out all fields of the first tweet
Hint: You might want to use method keys() of the dictionary
'''
# INSERT YOUR CODE HERE
print(k1_tweets[0]) #all field

'''
Write your code to print out the text of the first  tweet collected for each keyword.
'''

print("\nThe text of the first tweet for \"{}\":\n".format(keywords[0]))
# INSERT YOUR CODE HERE
print(k1_tweets[0]['text'])

print("\nThe text of the first tweet for \"{}\":\n".format(keywords[1]))
# INSERT YOUR CODE HERE
print(k2_tweets[0]['text'])

print('\nThe text of the first tweet for \"{}\":\n'.format(keywords[2]))
# INSERT YOUR CODE HERE
print(k3_tweets[0]['text'])
# Out:
# {'created_at': 'Wed May 20 08:13:37 +0000 2020', 'id': 1263020037687767042, 'id_str': '1263020037687767042', 'text': '@BlakeCarterAU Pizza actually ! \nBut dessert may of just changed 😜', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'BlakeCarterAU', 'name': 'Blake Carter - MELB', 'id': 896548729964027906, 'id_str': '896548729964027906', 'indices': [0, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1263000550024417280, 'in_reply_to_status_id_str': '1263000550024417280', 'in_reply_to_user_id': 896548729964027906, 'in_reply_to_user_id_str': '896548729964027906', 'in_reply_to_screen_name': 'BlakeCarterAU', 'user': {'id': 1000930243878600704, 'id_str': '1000930243878600704', 'name': 'Mark 🍺', 'screen_name': 'baysidedad73', 'location': 'Melbourne, Victoria', 'description': 'Just a dad , loves his boy and a beer 🍺 Lover of all kinds of curves 😘', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 184, 'friends_count': 308, 'listed_count': 0, 'created_at': 'Mon May 28 02:42:21 +0000 2018', 'favourites_count': 18031, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 5600, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1185135029594116097/DKYrhODy_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1185135029594116097/DKYrhODy_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1000930243878600704/1556857195', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}
#
# The text of the first tweet for "pizza":
#
# @BlakeCarterAU Pizza actually !
# But dessert may of just changed 😜
#
# The text of the first tweet for "politics":
#
# @Only2The @elee_bella @kahlilbrown20 Left wing politics is all about love.
#
# I don't know what you think the differe… https://t.co/LRH28hy8Gm
#
# The text of the first tweet for "raccoon":
#
# Skyway Traffic - Kiss You (One Direction cover)

# %% [markdown]
# **Note**. When collecting data from the Internet, such as Twitter, it is important that we store the data collected in an appropriate format for later data analysis task. We have learned that json is a poplular lightweight data format that can be handy to store unstructured data. For example, with NoSQL we can directly query these files in a 'scaling out' fashion. These technologies are representative features of Big Data Analytics.
#
# The following function has been designed for you to save an object which is a list of dictionaries (such as k1_tweets variable) to a json file. **You will need this function for your next task**.

# %%
def save_to_json(obj, filename):
    """
    saves a list of dictionaries into a json file
    
    obj: list of dictionaries
    filename: filename
    """
    with open(filename, 'w') as fp:
        json.dump(obj, fp, indent=4, sort_keys=True)

# %% [markdown]
# **Instruction 1.7**. Use the function ***save_to_json()*** defined above, for each collection of tweets you have crawled for each keyword, save them into a file named **w.json** where **w** is the keyword.
#
# For example, if your keywords are 'w1', 'w2' and 'w3', then your code must generate three file w1.json, w2.json and w3.json. **Important: you must submit these files together with your notebook solution**.
#
# [**Total mark: 9**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Use the save_to_json() function defined above, for the collection of tweets 
you have crawled for each keyword, save them into a file named w.json where w is the keyword, taken from keywords list.
'''
# saving the tweets in three json files, one for each keyword
#INSERT YOUR CODE HERE
jsonFileName1 = keywords[0]+".json"
jsonFileName2 = keywords[1]+".json"
jsonFileName3 = keywords[2]+".json"

save_to_json(k1_tweets, jsonFileName1)
save_to_json(k2_tweets, jsonFileName2)
save_to_json(k3_tweets, jsonFileName3)

# %% [markdown]
# ###                                     END OF PART 1
# ----

# %% [markdown]
# ## Part 2: Data Analytics
#
# The second part of this assignment will examine your skills and knowlege in data manipulation and analysis tasks. It includes three main components:
#
# **Part 2A**. For each keyword, you will be required to load the tweets from your saved json files (from Part 1) and filter out all tweets that are too short.
#
# **Part 2B**. Using your knowledge from practical sessions 5, 6 and 7, you will be required to construct the term-by-document matrix for the tweets and to perform visualisation tasks to understand them.
#
# **Part 2C**. You will apply the Kmeans clustering algorithm to cluster your tweets and report the clustering results.
#
# ***Follow the instructions below to complete your assigned tasks***.

# %% [markdown]
# ### Part 2A: Load and Filter Tweets from Files

# %% [markdown]
# **Instruction 2.1**. The following function, named ***read_json_file()***, has been partially implemented to load data from a json file. This function will be used later on to load three json files you have saved from Part 1. Your task is to insert your own code where instructed to complete this function.
#
# [**Total mark: 4**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Insert your own code where instructed to complete this function
'''
def read_json_file(filename):
    """
    reads from a json file and saves the result in a list named data
    """
    with open(filename, 'r') as fp:
    # INSERT THE MISSING PIECE OF CODE HERE
        content = fp.read()
    data = json.loads(content)
    return data

# %% [markdown]
# **Instruction 2.2**. Now use the ***read_json_file()*** function defined above, write three function calls to load data from three json files you have saved from Part 1.
#
# [**Total mark: 9**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write three function calls to load data from three json files you have saved from Part 1.
'''

k1_tweets = read_json_file(jsonFileName1)
k2_tweets = read_json_file(jsonFileName2)
k3_tweets = read_json_file(jsonFileName3)

# %% [markdown]
# **Instruction 2.3**. To examine the number of tweets loaded from your data files, write your code to print out the number of tweets containes in three variables: ***k1_tweets, k2_tweets*** and ***k3_tweets***.
#
# [**Total mark: 3**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your code to print out the number of tweets containes in three variables: 
k1_tweets, k2_tweets and k3_tweets
'''
#INSERT YOUR CODE HERE
def get_tweets_count(keyword ,tweets): 
    print("keyword :"+keyword+"  collected "+str(len(tweets))+" tweets")


get_tweets_count(keywords[0],k1_tweets)
get_tweets_count(keywords[1],k2_tweets)
get_tweets_count(keywords[2],k3_tweets)
# Out:
# keyword :pizza  collected 210 tweets
# keyword :politics  collected 208 tweets
# keyword :raccoon  collected 200 tweets

# %% [markdown]
# **Note**. When analysing tweets and text documents in general, an important analytics skill is to pre-process and filter the data into the form that one can start to apply analytics methods to extract knowledge.
#
# Tweets that are too short might not be useful for analysis. We define that tweets having less than 50 characters are short and should be remove.

# %% [markdown]
# **Instruction 2.4**. In this task, you need to filter all short tweets.
#
# 1. Write a function called `is_short_tweet` that takes a tweet as an input and return True if the text of the tweet has less than 50 characters and False otherwise. **(6 marks)**
#
# 2. Write your codes to remove all tweets that have less than 50 characters in variables ***k1_tweets***, ***k2_tweets*** and ***k3_tweets*** and store the results in the new variables ***k1_tweets_filtered***, ***k2_tweets_filtered*** and ***k3_tweets_filtered***, respectively. **(8 marks)**
#
# [**Total mark: 14**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
def is_short_tweet(tweet):
    '''
    Check if the text of "tweet" has less than 50 characters
    '''
    # INSERT YOUR CODE HERE
    isShortTweet = False
    if (len(tweet['text']) < 50):
        isShortTweet = True
    return isShortTweet

def filter_out_short_Tweet(tweets):
    filteredTweets = []
    for tweet in tweets:
        if not is_short_tweet(tweet):
            filteredTweets.append(tweet)
    return filteredTweets

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODES IN THIS CELL
'''
Write your codes to remove all tweets which have less than 50 characters in variables 
k1_tweets, k2_tweets and k3_tweets and store the results in the new variables 
k1_tweets_filtered, k2_tweets_filtered and k3_tweets_filtered respectively
'''
# INSERT YOUR CODE HERE
k1_tweets_filtered = filter_out_short_Tweet(k1_tweets)
k2_tweets_filtered = filter_out_short_Tweet(k2_tweets)
k3_tweets_filtered = filter_out_short_Tweet(k3_tweets)

# these lines below print the number of tweets for each keyword before and after filtered.
print(len(k1_tweets), len(k1_tweets_filtered))
print(len(k2_tweets), len(k2_tweets_filtered))
print(len(k3_tweets), len(k3_tweets_filtered))
# Out:
# 210 186
# 208 206
# 200 191

# %% [markdown]
# **Instruction 2.5**. For each keyword, print out the number of tweets that have been removed.
#
# [**Total mark: 3**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
For each keyword, print out the number of tweets that have been removed.
'''
nRemovedTweets1 = len(k1_tweets) - len(k1_tweets_filtered)
nRemovedTweets2 = len(k2_tweets) - len(k2_tweets_filtered)
nRemovedTweets3 = len(k3_tweets) - len(k3_tweets_filtered)

print("numbers of removed tweets is {} for keyword {}".format(str(nRemovedTweets1),keywords[0]))
print("numbers of removed tweets is {} for keyword {}".format(str(nRemovedTweets2),keywords[1]))
print("numbers of removed tweets is {} for keyword {}".format(str(nRemovedTweets3),keywords[2]))
# INSERT YOUR CODE HERE
# Out:
# numbers of removed tweets is 24 for keyword pizza
# numbers of removed tweets is 2 for keyword politics
# numbers of removed tweets is 9 for keyword raccoon

# %% [markdown]
# **Instruction 2.6**. To examine what the tweets look like after being loaded from the data files and filtered, in the cell below write your code to print out the first **5** tweets for each keyword.
#
# You **must** use the variables ***k1_tweets_filtered, k2_tweets_filtered*** and ***k3_tweets_filtered*** which have stored the data after the filtering process for this task.
#
# [**Total mark: 4**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your code to print out the first 5 tweets for each keyword.
You must use the variables k1_tweets_filtered, k2_tweets_filtered and k3_tweets_filtered 
which have stored the data after the filtering process for this task.

Hint: Using tweet['text'] for tweet in k1_tweets_filtered
'''

print('The first 5 tweets for \"{}\":\n'.format(keywords[0]))
# INSERT YOUR CODE HERE
for i in range (0,5):
    print(k1_tweets_filtered[i])

print('\nThe first 5 tweets for \"{}\":\n'.format(keywords[1]))
# INSERT YOUR CODE HERE 
for i in range (0,5):
    print(k2_tweets_filtered[i])

print('\nThe first 5 tweets for \"{}\":\n'.format(keywords[2]))
# INSERT YOUR CODE HERE
for i in range (0,5):
    print(k3_tweets_filtered[i])
# Out:
# The first 5 tweets for "pizza":
#
# {'contributors': None, 'coordinates': None, 'created_at': 'Wed May 20 08:13:37 +0000 2020', 'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': [{'id': 896548729964027906, 'id_str': '896548729964027906', 'indices': [0, 14], 'name': 'Blake Carter - MELB', 'screen_name': 'BlakeCarterAU'}]}, 'favorite_count': 0, 'favorited': False, 'geo': None, 'id': 1263020037687767042, 'id_str': '1263020037687767042', 'in_reply_to_screen_name': 'BlakeCarterAU', 'in_reply_to_status_id': 1263000550024417280, 'in_reply_to_status_id_str': '1263000550024417280', 'in_reply_to_user_id': 896548729964027906, 'in_reply_to_user_id_str': '896548729964027906', 'is_quote_status': False, 'lang': 'en', 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'place': None, 'retweet_count': 0, 'retweeted': False, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'text': '@BlakeCarterAU Pizza actually ! \nBut dessert may of just changed 😜', 'truncated': False, 'user': {'contributors_enabled': False, 'created_at': 'Mon May 28 02:42:21 +0000 2018', 'default_profile': True, 'default_profile_image': False, 'description': 'Just a dad , loves his boy and a beer 🍺 Lover of all kinds of curves 😘', 'entities': {'description': {'urls': []}}, 'favourites_count': 18031, 'follow_request_sent': False, 'followers_count': 184, 'following': False, 'friends_count': 308, 'geo_enabled': False, 'has_extended_profile': False, 'id': 1000930243878600704, 'id_str': '1000930243878600704', 'is_translation_enabled': False, 'is_translator': False, 'lang': None, 'listed_count': 0, 'location': 'Melbourne, Victoria', 'name': 'Mark 🍺', 'notifications': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1000930243878600704/1556857195', 'profile_image_url': 'http://pbs.twimg.com/profile_images/1185135029594116097/DKYrhODy_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1185135029594116097/DKYrhODy_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'protected': False, 'screen_name': 'baysidedad73', 'statuses_count': 5600, 'time_zone': None, 'translator_type': 'none', 'url': None, 'utc_offset': None, 'verified': False}}
# {'contributors': None, 'coordinates': None, 'created_at': 'Wed May 20 07:42:30 +0000 2020', 'entities': {'hashtags': [{'indices': [57, 66], 'text': 'afterpay'}, {'indices': [84, 93], 'text': 'UberEats'}, {'indices': [94, 104], 'text': 'helpmeout'}], 'symbols': [], 'urls': [], 'user_mentions': []}, 'favorite_count': 1, 'favorited': False, 'geo': None, 'id': 1263012206909616130, 'id_str': '1263012206909616130', 'in_reply_to_screen_name': None, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'is_quote_status': False, 'lang': 'en', 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'place': None, 'retweet_count': 0, 'retweeted': False, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'text': 'Pay day is tomorrow why can’t I just after pay a pizza ? #afterpay just a thought ? #UberEats #helpmeout', 'truncated': False, 'user': {'contributors_enabled': False, 'created_at': 'Thu Aug 17 08:58:15 +0000 2017', 'default_profile': True, 'default_profile_image': False, 'description': 'Footy tragic', 'entities': {'description': {'urls': []}}, 'favourites_count': 1512, 'follow_request_sent': False, 'followers_count': 96, 'following': False, 'friends_count': 830, 'geo_enabled': False, 'has_extended_profile': True, 'id': 898106688657530880, 'id_str': '898106688657530880', 'is_translation_enabled': False, 'is_translator': False, 'lang': None, 'listed_count': 0, 'location': 'Melbourne, Victoria', 'name': 'Mitch Strahan', 'notifications': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/898106688657530880/1502960402', 'profile_image_url': 'http://pbs.twimg.com/profile_images/1131481489185443840/KBIlMCeX_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1131481489185443840/KBIlMCeX_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'protected': False, 'screen_name': 'mitch_strahan_', 'statuses_count': 312, 'time_zone': None, 'translator_type': 'none', 'url': None, 'utc_offset': None, 'verified': False}}
# {'contributors': None, 'coordinates': None, 'created_at': 'Wed May 20 06:43:18 +0000 2020', 'entities': {'hashtags': [], 'symbols': [], 'urls': [{'display_url': 'twitter.com/i/web/status/1…', 'expanded_url': 'https://twitter.com/i/web/status/1262997309970739205', 'indices': [117, 140], 'url': 'https://t.co/WiJihGGviD'}], 'user_mentions': []}, 'favorite_count': 0, 'favorited': False, 'geo': None, 'id': 1262997309970739205, 'id_str': '1262997309970739205', 'in_reply_to_screen_name': None, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'is_quote_status': False, 'lang': 'en', 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'place': None, 'possibly_sensitive': False, 'retweet_count': 0, 'retweeted': False, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'text': 'As a true Australian Patriot, I like my tinnies COLD, my pizza EGGED, and my salted caramel Tim tams with salt from… https://t.co/WiJihGGviD', 'truncated': True, 'user': {'contributors_enabled': False, 'created_at': 'Mon Nov 05 23:09:23 +0000 2012', 'default_profile': False, 'default_profile_image': False, 'description': "Don't read into any of this.", 'entities': {'description': {'urls': []}, 'url': {'urls': [{'display_url': 'deathbyinternet.com', 'expanded_url': 'http://deathbyinternet.com', 'indices': [0, 23], 'url': 'https://t.co/6Fw70rN4Ku'}]}}, 'favourites_count': 3758, 'follow_request_sent': False, 'followers_count': 171, 'following': False, 'friends_count': 703, 'geo_enabled': True, 'has_extended_profile': False, 'id': 928583678, 'id_str': '928583678', 'is_translation_enabled': False, 'is_translator': False, 'lang': None, 'listed_count': 4, 'location': 'Melbourne', 'name': 'Phoenix Trinidad(dy)', 'notifications': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/987199205046337536/1ECyF8Di_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/987199205046337536/1ECyF8Di_normal.jpg', 'profile_link_color': '000000', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': False, 'protected': False, 'screen_name': 'PhoenixTrinidad', 'statuses_count': 488, 'time_zone': None, 'translator_type': 'none', 'url': 'https://t.co/6Fw70rN4Ku', 'utc_offset': None, 'verified': False}}
# {'contributors': None, 'coordinates': None, 'created_at': 'Wed May 20 06:23:18 +0000 2020', 'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': [{'id': 1078966464827146240, 'id_str': '1078966464827146240', 'indices': [0, 16], 'name': 'JackAlphaSystem', 'screen_name': 'JackAlphaSyste1'}]}, 'favorite_count': 1, 'favorited': False, 'geo': None, 'id': 1262992275837083648, 'id_str': '1262992275837083648', 'in_reply_to_screen_name': 'JackAlphaSyste1', 'in_reply_to_status_id': 1261906046093651968, 'in_reply_to_status_id_str': '1261906046093651968', 'in_reply_to_user_id': 1078966464827146240, 'in_reply_to_user_id_str': '1078966464827146240', 'is_quote_status': False, 'lang': 'en', 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'place': None, 'retweet_count': 1, 'retweeted': False, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'text': '@JackAlphaSyste1 but you can eat as much virtual pizza as you want', 'truncated': False, 'user': {'contributors_enabled': False, 'created_at': 'Wed Jun 30 02:19:26 +0000 2010', 'default_profile': False, 'default_profile_image': False, 'description': 'Hooves of Fire is a fast paced horse racing game where you can breed, train and race horses against players around the world.', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'display_url': 'hoovesoffire.com', 'expanded_url': 'https://www.hoovesoffire.com', 'indices': [0, 23], 'url': 'https://t.co/Hozs6eWGoz'}]}}, 'favourites_count': 356, 'follow_request_sent': False, 'followers_count': 3269, 'following': False, 'friends_count': 673, 'geo_enabled': False, 'has_extended_profile': False, 'id': 161133082, 'id_str': '161133082', 'is_translation_enabled': False, 'is_translator': False, 'lang': None, 'listed_count': 7, 'location': 'Melbourne, Australia ', 'name': 'Hooves of Fire', 'notifications': False, 'profile_background_color': '2F6B2F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/161133082/1388626441', 'profile_image_url': 'http://pbs.twimg.com/profile_images/882081285065158656/6N2v2y8O_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/882081285065158656/6N2v2y8O_normal.jpg', 'profile_link_color': '698C23', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'protected': False, 'screen_name': 'HoovesofFire', 'statuses_count': 1069, 'time_zone': None, 'translator_type': 'none', 'url': 'https://t.co/Hozs6eWGoz', 'utc_offset': None, 'verified': False}}
# {'contributors': None, 'coordinates': None, 'created_at': 'Wed May 20 04:48:36 +0000 2020', 'entities': {'hashtags': [], 'symbols': [], 'urls': [{'display_url': 'twitter.com/i/web/status/1…', 'expanded_url': 'https://twitter.com/i/web/status/1262968442828750849', 'indices': [117, 140], 'url': 'https://t.co/3XQbPN5Zmf'}], 'user_mentions': []}, 'favorite_count': 6, 'favorited': False, 'geo': None, 'id': 1262968442828750849, 'id_str': '1262968442828750849', 'in_reply_to_screen_name': None, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'is_quote_status': False, 'lang': 'en', 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'place': None, 'possibly_sensitive': False, 'retweet_count': 3, 'retweeted': False, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'text': 'Interesting but super sad -  episode of Full Story about the future of hospo.... \ngreat if you love Dominos pizza..… https://t.co/3XQbPN5Zmf', 'truncated': True, 'user': {'contributors_enabled': False, 'created_at': 'Tue Feb 24 02:52:20 +0000 2009', 'default_profile': False, 'default_profile_image': False, 'description': "Journalist at Guardian Australia. \nWeekly column: Brigid Delaney's Diary. \nAuthor of Wellmania, Wild Things & This Restless Life. \nSide hustle: travel writer", 'entities': {'description': {'urls': []}, 'url': {'urls': [{'display_url': 'brigiddelaney.com.au', 'expanded_url': 'http://www.brigiddelaney.com.au', 'indices': [0, 22], 'url': 'http://t.co/P9oWy97vcV'}]}}, 'favourites_count': 19920, 'follow_request_sent': False, 'followers_count': 12836, 'following': False, 'friends_count': 3263, 'geo_enabled': False, 'has_extended_profile': False, 'id': 21722675, 'id_str': '21722675', 'is_translation_enabled': False, 'is_translator': False, 'lang': None, 'listed_count': 224, 'location': 'Sydney and Melbourne', 'name': 'Brigid Delaney', 'notifications': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1149476040693051393/uT4LFCdO_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1149476040693051393/uT4LFCdO_normal.jpg', 'profile_link_color': 'E81C4F', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'protected': False, 'screen_name': 'BrigidWD', 'statuses_count': 59110, 'time_zone': None, 'translator_type': 'none', 'url': 'http://t.co/P9oWy97vcV', 'utc_offset': None, 'verified': True}}
#
# The first 5 tweets for "politics":
#
# {'contributors': None, 'coordinates': None, 'created_at': 'Wed May 20 08:14:15 +0000 2020', 'entities': {'hashtags': [], 'symbols': [], 'urls': [{'display_url': 'twitter.com/i/web/status/1…', 'expanded_url': 'https://twitter.com/i/web/status/1263020196983267328', 'indices': [117, 140], 'url': 'https://t.co/LRH28hy8Gm'}], 'user_mentions': [{'id': 1221316949830860800, 'id_str': '1221316949830860800', 'indices': [0, 9], 'name': 'TheOneOnly2', 'screen_name': 'Only2The'}, {'id': 868101092676050944, 'id_str': '868101092676050944', 'indices': [10, 21], 'name': 'Ella Lee', 'screen_name': 'elee_bella'}, {'id': 1169830064357142529, 'id_str': '1169830064357142529', 'indices': [22, 36], 'name': 'kahlil brown', 'screen_name': 'kahlilbrown20'}]}, 'favorite_count': 1, 'favorited': False, 'geo': None, 'id': 1263020196983267328, 'id_str': '1263020196983267328', 'in_reply_to_screen_name': 'Only2The', 'in_reply_to_status_id': 1263018656222474240, 'in_reply_to_status_id_str': '1263018656222474240', 'in_reply_to_user_id': 1221316949830860800, 'in_reply_to_user_id_str': '1221316949830860800', 'is_quote_status': False, 'lang': 'en', 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'place': None, 'retweet_count': 1, 'retweeted': False, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'text': "@Only2The @elee_bella @kahlilbrown20 Left wing politics is all about love.\n\nI don't know what you think the differe… https://t.co/LRH28hy8Gm", 'truncated': True, 'user': {'contributors_enabled': False, 'created_at': 'Sat Jun 04 12:25:35 +0000 2016', 'default_profile': False, 'default_profile_image': False, 'description': 'Wirlomin Noongar, Black&Write Indigenous Writing Fellow. Novels: The Old Lie,Terra Nullius: AU - @HachetteAus USA - @smallbeerpress (Photo, Jen Dainer) she/her', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'display_url': 'clairegcoleman.com', 'expanded_url': 'http://www.clairegcoleman.com', 'indices': [0, 23], 'url': 'https://t.co/PvnKb0WL9f'}]}}, 'favourites_count': 40771, 'follow_request_sent': False, 'followers_count': 7884, 'following': False, 'friends_count': 837, 'geo_enabled': True, 'has_extended_profile': True, 'id': 739070594688262149, 'id_str': '739070594688262149', 'is_translation_enabled': False, 'is_translator': False, 'lang': None, 'listed_count': 80, 'location': 'Melbourne, Victoria', 'name': 'Claire G. Coleman', 'notifications': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/739070594688262149/1553906460', 'profile_image_url': 'http://pbs.twimg.com/profile_images/1196245789623779328/ErjjQmrA_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1196245789623779328/ErjjQmrA_normal.jpg', 'profile_link_color': '4F7C6F', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'protected': False, 'screen_name': 'clairegcoleman', 'statuses_count': 31191, 'time_zone': None, 'translator_type': 'none', 'url': 'https://t.co/PvnKb0WL9f', 'utc_offset': None, 'verified': False}}
# {'contributors': None, 'coordinates': None, 'created_at': 'Wed May 20 08:01:06 +0000 2020', 'entities': {'hashtags': [{'indices': [0, 10], 'text': 'Australia'}, {'indices': [17, 29], 'text': 'coronavirus'}, {'indices': [52, 66], 'text': 'Cybersecurity'}], 'symbols': [], 'urls': [{'display_url': 'afr.com/politics/feder…', 'expanded_url': 'https://www.afr.com/politics/federal/australia-slams-coronavirus-related-cyber-attacks-20200520-p54urp', 'indices': [67, 90], 'url': 'https://t.co/47ySwHmtIz'}], 'user_mentions': []}, 'favorite_count': 0, 'favorited': False, 'geo': None, 'id': 1263016890001047553, 'id_str': '1263016890001047553', 'in_reply_to_screen_name': None, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'is_quote_status': False, 'lang': 'en', 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'place': None, 'possibly_sensitive': False, 'retweet_count': 0, 'retweeted': False, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'text': '#Australia slams #coronavirus crisis cyber attacks. #Cybersecurity https://t.co/47ySwHmtIz', 'truncated': False, 'user': {'contributors_enabled': False, 'created_at': 'Thu Apr 08 02:11:19 +0000 2010', 'default_profile': False, 'default_profile_image': False, 'description': 'Project wrangler & business mentor. Owner of ideas generator, Rex Ideas. Innovation & better business advocate. AI tragic! Agtech & cybersecurity enthusiast.', 'entities': {'description': {'urls': []}}, 'favourites_count': 1981, 'follow_request_sent': False, 'followers_count': 451, 'following': False, 'friends_count': 368, 'geo_enabled': True, 'has_extended_profile': True, 'id': 130704747, 'id_str': '130704747', 'is_translation_enabled': False, 'is_translator': False, 'lang': None, 'listed_count': 258, 'location': 'Melbourne, Australia', 'name': 'Collins Rex', 'notifications': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif', 'profile_background_tile': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/130704747/1586743547', 'profile_image_url': 'http://pbs.twimg.com/profile_images/1249519087312494592/dn7gvjRe_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1249519087312494592/dn7gvjRe_normal.jpg', 'profile_link_color': '981CEB', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'protected': False, 'screen_name': 'QueenRex', 'statuses_count': 9866, 'time_zone': None, 'translator_type': 'none', 'url': None, 'utc_offset': None, 'verified': False}}
# {'contributors': None, 'coordinates': None, 'created_at': 'Wed May 20 08:00:18 +0000 2020', 'entities': {'hashtags': [], 'symbols': [], 'urls': [{'display_url': 'twitter.com/i/web/status/1…', 'expanded_url': 'https://twitter.com/i/web/status/1263016686627753985', 'indices': [117, 140], 'url': 'https://t.co/Ggdp9mUawd'}], 'user_mentions': [{'id': 71918331, 'id_str': '71918331', 'indices': [55, 62], 'name': 'Off The Record', 'screen_name': 'OTRRRR'}, {'id': 27668977, 'id_str': '27668977', 'indices': [99, 110], 'name': 'Steve Earle', 'screen_name': 'SteveEarle'}]}, 'favorite_count': 3, 'favorited': False, 'geo': None, 'id': 1263016686627753985, 'id_str': '1263016686627753985', 'in_reply_to_screen_name': None, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'is_quote_status': False, 'lang': 'en', 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'place': None, 'possibly_sensitive': False, 'retweet_count': 1, 'retweeted': False, 'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>', 'text': 'Politics, theatre, cultural divides, and disasters. On @OTRRRR Brian Wise chats with the legendary @SteveEarle abou… https://t.co/Ggdp9mUawd', 'truncated': True, 'user': {'contributors_enabled': False, 'created_at': 'Mon Apr 27 10:53:40 +0000 2009', 'default_profile': False, 'default_profile_image': False, 'description': 'Independent Radio in Melbourne 102.7FM. Support & subscribe by calling us on 9388 1027 or visit https://t.co/ym34IlKBt4', 'entities': {'description': {'urls': [{'display_url': 'rrr.org.au', 'expanded_url': 'http://rrr.org.au', 'indices': [96, 119], 'url': 'https://t.co/ym34IlKBt4'}]}, 'url': {'urls': [{'display_url': 'rrr.org.au', 'expanded_url': 'http://www.rrr.org.au', 'indices': [0, 22], 'url': 'http://t.co/tdWKz4tjtr'}]}}, 'favourites_count': 5652, 'follow_request_sent': False, 'followers_count': 59905, 'following': False, 'friends_count': 618, 'geo_enabled': True, 'has_extended_profile': False, 'id': 35715963, 'id_str': '35715963', 'is_translation_enabled': False, 'is_translator': False, 'lang': None, 'listed_count': 466, 'location': 'Melbourne, Victoria', 'name': '3rrrfm', 'notifications': False, 'profile_background_color': '131516', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/35715963/1588293904', 'profile_image_url': 'http://pbs.twimg.com/profile_images/1256021770865238016/wZzL6uHA_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256021770865238016/wZzL6uHA_normal.jpg', 'profile_link_color': 'ED1C24', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'protected': False, 'screen_name': '3RRRFM', 'statuses_count': 16339, 'time_zone': None, 'translator_type': 'none', 'url': 'http://t.co/tdWKz4tjtr', 'utc_offset': None, 'verified': False}}
# {'contributors': None, 'coordinates': None, 'created_at': 'Wed May 20 07:59:12 +0000 2020', 'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': [{'id': 1169830064357142529, 'id_str': '1169830064357142529', 'indices': [0, 14], 'name': 'kahlil brown', 'screen_name': 'kahlilbrown20'}]}, 'favorite_count': 1, 'favorited': False, 'geo': None, 'id': 1263016408247496704, 'id_str': '1263016408247496704', 'in_reply_to_screen_name': 'kahlilbrown20', 'in_reply_to_status_id': 1263015972593520640, 'in_reply_to_status_id_str': '1263015972593520640', 'in_reply_to_user_id': 1169830064357142529, 'in_reply_to_user_id_str': '1169830064357142529', 'is_quote_status': False, 'lang': 'en', 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'place': None, 'retweet_count': 0, 'retweeted': False, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'text': '@kahlilbrown20 Not at all. If they are Australian they are commenting on local politics. Calling for our annexation by the USA is treason.', 'truncated': False, 'user': {'contributors_enabled': False, 'created_at': 'Sat Jun 04 12:25:35 +0000 2016', 'default_profile': False, 'default_profile_image': False, 'description': 'Wirlomin Noongar, Black&Write Indigenous Writing Fellow. Novels: The Old Lie,Terra Nullius: AU - @HachetteAus USA - @smallbeerpress (Photo, Jen Dainer) she/her', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'display_url': 'clairegcoleman.com', 'expanded_url': 'http://www.clairegcoleman.com', 'indices': [0, 23], 'url': 'https://t.co/PvnKb0WL9f'}]}}, 'favourites_count': 40771, 'follow_request_sent': False, 'followers_count': 7884, 'following': False, 'friends_count': 837, 'geo_enabled': True, 'has_extended_profile': True, 'id': 739070594688262149, 'id_str': '739070594688262149', 'is_translation_enabled': False, 'is_translator': False, 'lang': None, 'listed_count': 80, 'location': 'Melbourne, Victoria', 'name': 'Claire G. Coleman', 'notifications': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/739070594688262149/1553906460', 'profile_image_url': 'http://pbs.twimg.com/profile_images/1196245789623779328/ErjjQmrA_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1196245789623779328/ErjjQmrA_normal.jpg', 'profile_link_color': '4F7C6F', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'protected': False, 'screen_name': 'clairegcoleman', 'statuses_count': 31191, 'time_zone': None, 'translator_type': 'none', 'url': 'https://t.co/PvnKb0WL9f', 'utc_offset': None, 'verified': False}}
# {'contributors': None, 'coordinates': None, 'created_at': 'Wed May 20 07:54:28 +0000 2020', 'entities': {'hashtags': [], 'symbols': [], 'urls': [{'display_url': 'twitter.com/i/web/status/1…', 'expanded_url': 'https://twitter.com/i/web/status/1263015218747039744', 'indices': [121, 144], 'url': 'https://t.co/hvZxXFMVT9'}], 'user_mentions': [{'id': 16734909, 'id_str': '16734909', 'indices': [0, 16], 'name': 'Malcolm Turnbull', 'screen_name': 'TurnbullMalcolm'}]}, 'favorite_count': 0, 'favorited': False, 'geo': None, 'id': 1263015218747039744, 'id_str': '1263015218747039744', 'in_reply_to_screen_name': 'TurnbullMalcolm', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': 16734909, 'in_reply_to_user_id_str': '16734909', 'is_quote_status': False, 'lang': 'en', 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'place': None, 'possibly_sensitive': False, 'retweet_count': 0, 'retweeted': False, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'text': "@TurnbullMalcolm Great book! It's like getting an in depth look into how a political party runs behind the scenes &amp;… https://t.co/hvZxXFMVT9", 'truncated': True, 'user': {'contributors_enabled': False, 'created_at': 'Tue May 20 12:44:04 +0000 2014', 'default_profile': False, 'default_profile_image': False, 'description': 'Mining Engineer, Environmental Scientist. Masters in Entrepreneurship & Innovation. Love to travel, meet people, help others, volunteer & spend time with family', 'entities': {'description': {'urls': []}}, 'favourites_count': 4069, 'follow_request_sent': False, 'followers_count': 60, 'following': False, 'friends_count': 225, 'geo_enabled': False, 'has_extended_profile': False, 'id': 2510311561, 'id_str': '2510311561', 'is_translation_enabled': False, 'is_translator': False, 'lang': None, 'listed_count': 0, 'location': 'Melbourne, Victoria', 'name': 'Jamie Gough', 'notifications': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1057815919697702913/gXzGA2_k_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1057815919697702913/gXzGA2_k_normal.jpg', 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'protected': False, 'screen_name': 'Jamie102Jamie', 'statuses_count': 218, 'time_zone': None, 'translator_type': 'none', 'url': None, 'utc_offset': None, 'verified': False}}
#
# The first 5 tweets for "raccoon":
#
# {'contributors': None, 'coordinates': None, 'created_at': 'Tue May 19 08:38:09 +0000 2020', 'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []}, 'favorite_count': 0, 'favorited': False, 'geo': None, 'id': 1262663823992881152, 'id_str': '1262663823992881152', 'in_reply_to_screen_name': None, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'is_quote_status': False, 'lang': 'en', 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'place': None, 'retweet_count': 0, 'retweeted': False, 'source': '<a href="http://twittbot.net/" rel="nofollow">twittbot.net</a>', 'text': 'Skyway Traffic - Just The Way You Are (Bruno Mars cover)', 'truncated': False, 'user': {'contributors_enabled': False, 'created_at': 'Wed May 15 10:15:22 +0000 2013', 'default_profile': False, 'default_profile_image': False, 'description': '', 'entities': {'description': {'urls': []}}, 'favourites_count': 0, 'follow_request_sent': False, 'followers_count': 114, 'following': False, 'friends_count': 0, 'geo_enabled': False, 'has_extended_profile': False, 'id': 1430098578, 'id_str': '1430098578', 'is_translation_enabled': False, 'is_translator': False, 'lang': None, 'listed_count': 9, 'location': 'Bandung, ID', 'name': '', 'notifications': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1430098578/1394352259', 'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000814066063/25785e5287087e8ff0902b9e1e59198d_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000814066063/25785e5287087e8ff0902b9e1e59198d_normal.jpeg', 'profile_link_color': '000000', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'protected': False, 'screen_name': 'acmdrmks', 'statuses_count': 580151, 'time_zone': None, 'translator_type': 'none', 'url': None, 'utc_offset': None, 'verified': False}}
# {'contributors': None, 'coordinates': None, 'created_at': 'Mon May 18 14:32:03 +0000 2020', 'entities': {'hashtags': [], 'media': [{'display_url': 'pic.twitter.com/T9kNstkEoI', 'expanded_url': 'https://twitter.com/kubikkreatif/status/1262390498133717000/photo/1', 'id': 1262390496288223235, 'id_str': '1262390496288223235', 'indices': [106, 129], 'media_url': 'http://pbs.twimg.com/media/EYTpd8sWsAM_ESP.png', 'media_url_https': 'https://pbs.twimg.com/media/EYTpd8sWsAM_ESP.png', 'sizes': {'large': {'h': 528, 'resize': 'fit', 'w': 916}, 'medium': {'h': 528, 'resize': 'fit', 'w': 916}, 'small': {'h': 392, 'resize': 'fit', 'w': 680}, 'thumb': {'h': 150, 'resize': 'crop', 'w': 150}}, 'type': 'photo', 'url': 'https://t.co/T9kNstkEoI'}], 'symbols': [], 'urls': [{'display_url': 'dlvr.it/RWtGfn', 'expanded_url': 'http://dlvr.it/RWtGfn', 'indices': [82, 105], 'url': 'https://t.co/oi0YuRTuoH'}], 'user_mentions': []}, 'extended_entities': {'media': [{'display_url': 'pic.twitter.com/T9kNstkEoI', 'expanded_url': 'https://twitter.com/kubikkreatif/status/1262390498133717000/photo/1', 'id': 1262390496288223235, 'id_str': '1262390496288223235', 'indices': [106, 129], 'media_url': 'http://pbs.twimg.com/media/EYTpd8sWsAM_ESP.png', 'media_url_https': 'https://pbs.twimg.com/media/EYTpd8sWsAM_ESP.png', 'sizes': {'large': {'h': 528, 'resize': 'fit', 'w': 916}, 'medium': {'h': 528, 'resize': 'fit', 'w': 916}, 'small': {'h': 392, 'resize': 'fit', 'w': 680}, 'thumb': {'h': 150, 'resize': 'crop', 'w': 150}}, 'type': 'photo', 'url': 'https://t.co/T9kNstkEoI'}]}, 'favorite_count': 0, 'favorited': False, 'geo': None, 'id': 1262390498133717000, 'id_str': '1262390498133717000', 'in_reply_to_screen_name': None, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'is_quote_status': False, 'lang': 'en', 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'place': None, 'possibly_sensitive': False, 'retweet_count': 0, 'retweeted': False, 'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>', 'text': 'Post-campaign analysis (PCA) – How to review a marketing campaign’s effectiveness https://t.co/oi0YuRTuoH https://t.co/T9kNstkEoI', 'truncated': False, 'user': {'contributors_enabled': False, 'created_at': 'Tue Feb 11 07:07:00 +0000 2014', 'default_profile': False, 'default_profile_image': False, 'description': '#DigitalMarketing Agency\nWe help your customers to find you!', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'display_url': 'kubikkreatif.com', 'expanded_url': 'http://kubikkreatif.com', 'indices': [0, 23], 'url': 'https://t.co/H10kVY83Vy'}]}}, 'favourites_count': 9, 'follow_request_sent': False, 'followers_count': 87, 'following': False, 'friends_count': 43, 'geo_enabled': False, 'has_extended_profile': False, 'id': 2337909036, 'id_str': '2337909036', 'is_translation_enabled': False, 'is_translator': False, 'lang': None, 'listed_count': 24, 'location': 'Bandung, Indonesia', 'name': 'Kubik Kreatif', 'notifications': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2337909036/1577950711', 'profile_image_url': 'http://pbs.twimg.com/profile_images/1212639287289634817/pwVbdkwj_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1212639287289634817/pwVbdkwj_normal.jpg', 'profile_link_color': '000000', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'protected': False, 'screen_name': 'kubikkreatif', 'statuses_count': 3340, 'time_zone': None, 'translator_type': 'none', 'url': 'https://t.co/H10kVY83Vy', 'utc_offset': None, 'verified': False}}
# {'contributors': None, 'coordinates': None, 'created_at': 'Mon May 18 02:38:11 +0000 2020', 'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []}, 'favorite_count': 0, 'favorited': False, 'geo': None, 'id': 1262210849441083393, 'id_str': '1262210849441083393', 'in_reply_to_screen_name': None, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'is_quote_status': False, 'lang': 'en', 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'place': None, 'retweet_count': 0, 'retweeted': False, 'source': '<a href="http://twittbot.net/" rel="nofollow">twittbot.net</a>', 'text': 'Skyway Traffic - Just The Way You Are (Bruno Mars cover)', 'truncated': False, 'user': {'contributors_enabled': False, 'created_at': 'Wed May 15 10:15:22 +0000 2013', 'default_profile': False, 'default_profile_image': False, 'description': '', 'entities': {'description': {'urls': []}}, 'favourites_count': 0, 'follow_request_sent': False, 'followers_count': 114, 'following': False, 'friends_count': 0, 'geo_enabled': False, 'has_extended_profile': False, 'id': 1430098578, 'id_str': '1430098578', 'is_translation_enabled': False, 'is_translator': False, 'lang': None, 'listed_count': 9, 'location': 'Bandung, ID', 'name': '', 'notifications': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1430098578/1394352259', 'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000814066063/25785e5287087e8ff0902b9e1e59198d_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000814066063/25785e5287087e8ff0902b9e1e59198d_normal.jpeg', 'profile_link_color': '000000', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'protected': False, 'screen_name': 'acmdrmks', 'statuses_count': 580151, 'time_zone': None, 'translator_type': 'none', 'url': None, 'utc_offset': None, 'verified': False}}
# {'contributors': None, 'coordinates': None, 'created_at': 'Sun May 17 16:18:39 +0000 2020', 'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []}, 'favorite_count': 2, 'favorited': False, 'geo': None, 'id': 1262054935123750913, 'id_str': '1262054935123750913', 'in_reply_to_screen_name': None, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'is_quote_status': False, 'lang': 'en', 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'place': None, 'retweet_count': 1, 'retweeted': False, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'text': 'I dont miss traffic jam or the smells of vehicles. I only miss my friends and hug them all...', 'truncated': False, 'user': {'contributors_enabled': False, 'created_at': 'Wed Aug 05 03:19:42 +0000 2009', 'default_profile': False, 'default_profile_image': False, 'description': 'community facilitator | perempuan menulis | kait nusantara', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'display_url': 'about.me/nitaroshita', 'expanded_url': 'http://about.me/nitaroshita', 'indices': [0, 23], 'url': 'https://t.co/pVunE9W8fn'}]}}, 'favourites_count': 1966, 'follow_request_sent': False, 'followers_count': 1244, 'following': False, 'friends_count': 434, 'geo_enabled': True, 'has_extended_profile': False, 'id': 63017393, 'id_str': '63017393', 'is_translation_enabled': False, 'is_translator': False, 'lang': None, 'listed_count': 29, 'location': 'Bandung', 'name': 'nita roshita', 'notifications': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme3/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme3/bg.gif', 'profile_background_tile': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/63017393/1445557336', 'profile_image_url': 'http://pbs.twimg.com/profile_images/1171574958754914304/wXSaUyzv_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1171574958754914304/wXSaUyzv_normal.jpg', 'profile_link_color': '7A2A0D', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'protected': False, 'screen_name': 'nroshita', 'statuses_count': 60891, 'time_zone': None, 'translator_type': 'none', 'url': 'https://t.co/pVunE9W8fn', 'utc_offset': None, 'verified': False}}
# {'contributors': None, 'coordinates': None, 'created_at': 'Sun May 17 13:21:38 +0000 2020', 'entities': {'hashtags': [], 'symbols': [], 'urls': [{'display_url': 'twitter.com/i/web/status/1…', 'expanded_url': 'https://twitter.com/i/web/status/1262010390327644160', 'indices': [117, 140], 'url': 'https://t.co/2EnMhCk4Fy'}], 'user_mentions': []}, 'favorite_count': 1, 'favorited': False, 'geo': None, 'id': 1262010390327644160, 'id_str': '1262010390327644160', 'in_reply_to_screen_name': None, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'is_quote_status': False, 'lang': 'en', 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'place': None, 'possibly_sensitive': False, 'retweet_count': 0, 'retweeted': False, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'text': 'You can Instantly Turn Absolutely any Webpage / Link (News Article, Quiz, YouTube Video, Shopify Offer, Affiliate L… https://t.co/2EnMhCk4Fy', 'truncated': True, 'user': {'contributors_enabled': False, 'created_at': 'Fri Jul 24 08:23:42 +0000 2009', 'default_profile': False, 'default_profile_image': False, 'description': 'Penulis Buku Buku Perbatasan - Pembicara, PeRiset dan PengKaji Pembangunan Perbatasant- Pertahanan https://t.co/IXz0fjj1ZX', 'entities': {'description': {'urls': [{'display_url': 'Perbatasan-bukuperbatasan.com', 'expanded_url': 'http://Perbatasan-bukuperbatasan.com', 'indices': [99, 122], 'url': 'https://t.co/IXz0fjj1ZX'}]}, 'url': {'urls': [{'display_url': 'harmenbatubara.com', 'expanded_url': 'http://www.harmenbatubara.com', 'indices': [0, 23], 'url': 'https://t.co/SUhRKBcgAF'}]}}, 'favourites_count': 2930, 'follow_request_sent': False, 'followers_count': 313, 'following': False, 'friends_count': 553, 'geo_enabled': True, 'has_extended_profile': False, 'id': 59727251, 'id_str': '59727251', 'is_translation_enabled': False, 'is_translator': False, 'lang': None, 'listed_count': 10, 'location': 'Bandung', 'name': 'harmen batubara', 'notifications': False, 'profile_background_color': 'C6E2EE', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif', 'profile_background_tile': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/59727251/1579253880', 'profile_image_url': 'http://pbs.twimg.com/profile_images/736416545581109248/Cj_0-zJp_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/736416545581109248/Cj_0-zJp_normal.jpg', 'profile_link_color': '1F98C7', 'profile_sidebar_border_color': 'C6E2EE', 'profile_sidebar_fill_color': 'DAECF4', 'profile_text_color': '663B12', 'profile_use_background_image': True, 'protected': False, 'screen_name': 'harmenharmen', 'statuses_count': 6187, 'time_zone': None, 'translator_type': 'none', 'url': 'https://t.co/SUhRKBcgAF', 'utc_offset': None, 'verified': False}}

# %% [markdown]
# ### Part 2B: Constructing Term-by-Document Matrix
#
# As we have learned in our class, in text analytics and in general dealing with unstructured data, to start perform **computational** tasks such as computing the distance between two documents, we need to represent them in **numerical** formats. A popular technique we have learned is the bag-of-word representation and the term-by-document matrix, also known as the vector-space model.
#
# This part of the assignment will require you to construct the term-by-document matrix for the tweets stored in three variables ***k1_tweets_filtered***, ***k2_tweets_filtered*** and ***k3_tweets_filtered***.

# %% [markdown]
# **Note.** Tweets are often not neat as you might have seen from early tasks. As tweet such as this
# ```
# Happy shopping👗👚👠👜 (with Vivi and Irmalia at @infomog) — https://t.co/fUGO9Eex1r
# ```
# might contain non-ASCII characters, emoticon, punctuations, etc. Building a bag-of-word representation **without** pre-processing the data can be ineffective.
#
# The following function ***pre_process()*** has been designed to preprocess the data for you.

# %%
def remove_non_ascii(s): return "".join(i for i in s if ord(i)<128)
def pre_process(doc):
    """
    pre-processes a doc
      * Converts the tweet into lower case,
      * removes the URLs,
      * removes the punctuations
      * tokenizes the tweet
      * removes words less that 3 characters
    """
    
    doc = doc.lower()
    # getting rid of non ascii codes
    doc = remove_non_ascii(doc)
    
    # replacing URLs
    url_pattern = "http://[^\s]+|https://[^\s]+|www.[^\s]+|[^\s]+\.com|bit.ly/[^\s]+"
    doc = re.sub(url_pattern, 'url', doc) 

    # removing dollars and usernames and other unnecessary stuff
    userdoll_pattern = "\$[^\s]+|\@[^\s]+|\&[^\s]+|\*[^\s]+|[0-9][^\s]+|\~[^\s]+"
    doc = re.sub(userdoll_pattern, '', doc)
    
    
    # removing punctuation
    punctuation = r"\(|\)|#|\'|\"|-|:|\\|\/|!|\?|_|,|=|;|>|<|\.|\@"
    doc = re.sub(punctuation, ' ', doc)
    
    return [w for w in doc.split() if len(w) > 2]

# %% [markdown]
# **Note**. For example, the following code will display the first tweet stored in the variable ***k1_tweets_filtered*** (for the first keyword) before and after it has been pre-processed.

# %%
tweet_k1 = k1_tweets_filtered[0]['text']
tweet_k1_processed = pre_process(tweet_k1)

print(tweet_k1)
# tweet_k1_processed is now a list of words. 
# We use ' '.join() method to join the list to a string.
print(' '.join(tweet_k1_processed))
# Out:
# @BlakeCarterAU Pizza actually !
# But dessert may of just changed 😜
# pizza actually but dessert may just changed

# %% [markdown]
# **Instruction 2.7**. Use the example above, write your code to display the **first** tweets stored in the variables ***k2_tweets_filtered*** and ***k2_tweets_filtered*** before and after they have been pre-processed using the function ***pre_process()*** supplied earlier.
#
# [**Total mark: 4**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Use the example above, write your code to display the first tweets stored in 
the variables k2_tweets_filtered and k3_tweets_filtered before and after they 
have been pre-processed using the function pre_process() supplied earlier.
'''

# INSERT YOUR CODE HERE
# For k2_tweets_filtered
tweet_k2 = k2_tweets_filtered[0]['text']
tweet_k2_processed = pre_process(tweet_k2)

print(tweet_k2)
# tweet_k1_processed is now a list of words. 
# We use ' '.join() method to join the list to a string.
print(' '.join(tweet_k2_processed))

# For k3_tweets_filtered
tweet_k3 = k3_tweets_filtered[0]['text']
tweet_k3_processed = pre_process(tweet_k3)

print(tweet_k3)
# tweet_k1_processed is now a list of words. 
# We use ' '.join() method to join the list to a string.
print(' '.join(tweet_k3_processed))
# Out:
# @Only2The @elee_bella @kahlilbrown20 Left wing politics is all about love.
#
# I don't know what you think the differe… https://t.co/LRH28hy8Gm
# left wing politics all about love don know what you think the differe url
# Skyway Traffic - Just The Way You Are (Bruno Mars cover)
# skyway traffic just the way you are bruno mars cover

# %% [markdown]
# **Instruction 2.8**. Write your code to pre-process and clean up all tweets stored in the variable ***k1_tweets_filtered***, ***k2_tweets_filtered*** and ***k3_tweets_filtered*** using the function ***pre_process()*** to result in new variables ***k1_tweets_processed***, ***k2_tweets_processed*** and ***k3_tweets_processed***.
#
# [**Total mark: 6**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your code to pre-process and clean up all tweets 
stored in the variable k1_tweets_filtered, k2_tweets_filtered and k3_tweets_filtered using the 
function pre_process() to result in new variables k1_tweets_processed, k2_tweets_processed 
and k3_tweets_processed.
'''
# INSERT YOUR CODE HERE
# Making processed lists
k1_tweets_processed = []
k2_tweets_processed = []
k3_tweets_processed = []

# process all the lists
for i in range(len(k1_tweets_filtered)):
    k1_tweets_processed.append(k1_tweets_filtered[i]['text']);
    
for i in range(len(k2_tweets_filtered)):
    k2_tweets_processed.append(k2_tweets_filtered[i]['text']);
    
for i in range(len(k2_tweets_filtered)):
    k2_tweets_processed.append(k2_tweets_filtered[i]['text']);

# %% [markdown]
# **Instruction 2.9**. Now, write your code to print out the **first 5 processed tweets** for each keyword *(the processed tweets are stored in **k1_tweets_processed**, **k2_tweets_processed** and **k3_tweets_processed**)*
#
# [**Total mark: 7**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Now write your code to print out the first 5 processed tweets for each keyword.
Hint: Each tweet in tweets_processed is now a list of words, not a string. 
      To print a string, you might need to use ' '.join(tweet), 
      when tweet is a processed tweet

'''

print('The first 5 processed tweets for k1_tweets_processed:')
# INSERT YOUR CODE HERE
print(k1_tweets_processed[:5])


print('\nThe first 5 processed tweets for k2_tweets_processed:')
# INSERT YOUR CODE HERE
print(k2_tweets_processed[:5])


print('\nThe first 5 processed tweets for k3_tweets_processed:')
# INSERT YOUR CODE HERE
print(k3_tweets_processed[:5])
# Out:
# The first 5 processed tweets for k1_tweets_processed:
# ['@BlakeCarterAU Pizza actually ! \nBut dessert may of just changed 😜', 'Pay day is tomorrow why can’t I just after pay a pizza ? #afterpay just a thought ? #UberEats #helpmeout', 'As a true Australian Patriot, I like my tinnies COLD, my pizza EGGED, and my salted caramel Tim tams with salt from… https://t.co/WiJihGGviD', '@JackAlphaSyste1 but you can eat as much virtual pizza as you want', 'Interesting but super sad -  episode of Full Story about the future of hospo.... \ngreat if you love Dominos pizza..… https://t.co/3XQbPN5Zmf']
#
# The first 5 processed tweets for k2_tweets_processed:
# ["@Only2The @elee_bella @kahlilbrown20 Left wing politics is all about love.\n\nI don't know what you think the differe… https://t.co/LRH28hy8Gm", '#Australia slams #coronavirus crisis cyber attacks. #Cybersecurity https://t.co/47ySwHmtIz', 'Politics, theatre, cultural divides, and disasters. On @OTRRRR Brian Wise chats with the legendary @SteveEarle abou… https://t.co/Ggdp9mUawd', '@kahlilbrown20 Not at all. If they are Australian they are commenting on local politics. Calling for our annexation by the USA is treason.', "@TurnbullMalcolm Great book! It's like getting an in depth look into how a political party runs behind the scenes &amp;… https://t.co/hvZxXFMVT9"]
#
# The first 5 processed tweets for k3_tweets_processed:
# []

# %% [markdown]
# **Note**. The following function ***construct_termdoc()*** has been implemented to construct the term-by-document matrix from a corpus of text data. **You will need this function for subsequent task**.

# %%
def construct_termdoc(docs, vocab=[]):
    """
    Construct a term-by-document-matrix
    
    docs: corpus
    vocab: pre-defined vocabulary
           if not supplied it will be automatically induced from the data
    
    returns the term-by-document matrix and the vocabulary of the passed corpus
    """
    
    # vocab is not passed
    if vocab == []:
        vocab = set()
        termdoc_sparse = []

        for doc in docs:       
            # computes the frequencies of doc
            doc_sparse = Counter(doc)    
            termdoc_sparse.append(doc_sparse)
            
            # update the vocab
            vocab.update(doc_sparse.keys())  

        vocab = list(vocab)
        vocab.sort()
    
    else:
        termdoc_sparse = []        
        for doc in docs:
            termdoc_sparse.append(Counter(doc))
            

    n_docs = len(docs)
    n_vocab = len(vocab)
    termdoc_dense = np.zeros((n_docs, n_vocab), dtype=int)

    for j, doc_sparse in enumerate(termdoc_sparse):
        for term, freq in doc_sparse.items():
            try:
                termdoc_dense[j, vocab.index(term)] = freq
            except:
                pass
            
    return termdoc_dense, vocab

# %% [markdown]
# **Instruction 2.10 (D)**. In the function ***construct_termdoc()***, a function **set** is used. Learn what this function does and explain its role in the function ***construct_termdoc()***. Write a brief answer.
#
# [**Total mark: 5**]

# %%
# In the function construct_termdoc(), a function "set" is used. Learn what this function does 
# and explain its role in the function construct_termdoc().
# YOU ARE REQUIRED TO INSERT YOUR COMMENT IN THIS CELL
#
# The set() function is to creat a 'Set' object. 
# On this case, the set() function is being used in order to make an ampty set of vocabs

# %% [markdown]
# **Note**. Now suppose that we would like to construct a term-by-document matrix for tweets collected for the **first keyword only**. The following piece of codes will do this by computing the term-by-document matrix and the vocabulary for tweets stored in **k1_tweets_processed**, print them out and visualise the corresponding term-by-document matrix stored in the variable ***k1_termdoc***. The corresponding vocabulary dictionary computed from this data will also be stored in the variable ***k1_vocab***.

# %%
'''
compute the term-by-document matrix and the the dictionary from the collection of 
tweets collected for the first keyword
'''
k1_termdoc, k1_vocab = construct_termdoc(k1_tweets_processed)

# print out the term-by-document matrix
print(k1_termdoc)
# print out the first 5 vocabulary entries
print(' '.join(k1_vocab[-5:]))  # print out only the first 5 vocabulary entries

# visualise the term-by-document matrix
fig, ax = plt.subplots(figsize=(10, 5))
ax.imshow(k1_termdoc)
ax.set_xlabel('term (vocabulary)')
ax.set_ylabel('documents (tweets)')
ax.set_title('Term-by-Document matrix from tweets collected for keyword \"{}\"'.format(keywords[0]))
# Out:
# [[ 1 10  1 ...  0  0  0]
#  [ 0 19  0 ...  0  0  0]
#  [ 0 22  0 ...  0  0  0]
#  ...
#  [ 0 22  0 ...  0  0  0]
#  [ 0 20  0 ...  0  0  0]
#  [ 0  7  0 ...  0  0  0]]
# 🤤 🤮 🥴 🥺 🧻
# Text(0.5, 1.0, 'Term-by-Document matrix from tweets collected for keyword "pizza"')

# %% [markdown]
# **Note**. Next, we would like to compute the pairwise distances between every two tweets. This will help us to see how similar tweets are. This is a computational task that would be *not* possible to do if we use the raw tweets.
#
# However, with the term-by-document matrix, each tweet now is vector and corresponds to a row in the term-by-document matrix. Hence, we can use the distance between vectors to compute the distance between tweets. This is also known as the **vector space model** in information retrieval literature.

# %% [markdown]
# **Instruction 2.11**. Your tasks are:
#
# 1. Define a function to compute and return the Euclidean distance between two vectors as we have learned from the class notes. **(5 marks)**
#
# 2. Define a function to compute and return the cosine distance between two vectors as we have learned from the class notes. **(5 marks)**
#
# 3. Construct a single function that returns two distance matrices ***euclidean_distance_matrix***, and ***cosine_distance_matrix***, whose elements (i,j) store the Eulidean distance and the cosine distance between tweets i-th and i-jth. **You will need this function for subsequent task**. **(6 marks)**
#
# **[Total mark: 16]**

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

def Euclidean_distance(x,y):
    '''
    Compute and return the Euclidean distance between two vectors x and y
    '''
    # INSERT YOUR CODE HERE
    d = x - y
    d = d ** 2
    return np.sqrt(d.sum())

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
def cosine_distance(x,y):
    '''
    Compute and return the cosine distance between two vectors x and y
    '''
    # INSERT YOUR CODE HERE
    try:
        num = (x*y).sum()
        denom = np.sqrt((x*x).sum()) * np.sqrt((y*y).sum())
        num += 0.0    # or use np.astype(float) to make sure of float division
        return num/denom
    except ValueError as e:
        print("Vectors passed to the function are not the same size")
        return None

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
The function takes the termdoc matrix as the input and computes variables called "euclidean_distance_matrix" 
and "cosine_distance_matrix", which are matrices whose elements (i,j) store the Eulidean distance 
and the cosine distance between tweet i-th and i-jth.

Hint: you should store the distance matrices in numpy arrays for easier implementation in subsequent tasks
'''
def compute_distance_matrices(termdoc):
    # INSERT YOUR CODE HERE
    distanceMatrices = []
    euclidean_distance_matrix = Euclidean_distance(termdoc[0], termdoc[1])
    cosine_distance_matrix = cosine_distance(termdoc[0], termdoc[1])
    distanceMatrices.append(euclidean_distance_matrix)
    distanceMatrices.append(cosine_distance_matrix)
    print(distanceMatrices)
    return distanceMatrices

# %% [markdown]
# **Instruction 2.12**.
#
# 1. Now you need to compute the distance matrices for **k1_termdoc** and then visualise these distance matrices. **(10 marks)**
#
# 2. Explain why cosine distance is always in the range between 0 and 1. **(5 marks)**
#
# 3. (HD) Using a scatter plot demonstrate relationship between Euclidean distance and cosine distance. **(5 marks)**
#
# 4. (HD) Explain why cosine distance increases if Euclidean distance decreases and vice versa. **(5 marks)**
#
#
# **[Total mark: 25]**

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

# compute the distance matrices for k1_termdoc using the function "compute_distance_matrices"
# INSERT YOUR CODE HERE
k1_cdm = compute_distance_matrices(k1_termdoc)

# Visualise the distance matrices for this keyword
# Hint: use imshow() and colorbar() functions
# INSERT YOUR CODE HERE
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(k1_cdm[0],k1_cdm[1])
ax.set_xlabel('euclidean distance')
ax.set_ylabel('cosine distance')
ax.set_title('Term-by-Document matrix from tweets collected for keyword \"{}\"'.format(keywords[0]))
# Out:
# [14.832396974191326, 0.9102185124496128]
# Text(0.5, 1.0, 'Term-by-Document matrix from tweets collected for keyword "pizza"')

# %%
# Explain why cosine distance is always in the range between 0 and 1.
# YOU ARE REQUIRED TO INSERT YOUR COMMENT IN THIS CELL
#

# %%
# Using a scatter plot demonstrate relationship between Euclidean distance and cosine distance.
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
# INSERT YOUR CODE HERE
plt.scatter(k1_cdm[0], k1_cdm[1])
plt.show()

# %%
# Explain why cosine distance increases if Euclidean distance decreases and vice versa.
# YOU ARE REQUIRED TO INSERT YOUR COMMENT IN THIS CELL
#

# %% [markdown]
# **Instruction 2.13**. Similar to the example above for the first keyword, your task is to write codes in the cell below to compute the term-by-document matrix and the vocabulary for tweets stored in ***k2_tweets_processed***, print out the first **5** vocabularies and visualise this term-by-document matrix.
#
# [**Total mark: 5**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your codes to compute the term-by-document matrix and the vocabulary for tweets stored 
in k2_tweets_processed
'''
# INSERT YOUR CODE HERE
k2_termdoc, k2_vocab = construct_termdoc(k2_tweets_processed)
'''
Write your code print out the first 5 vocabularies 
'''
# INSERT YOUR CODE HERE
print(' '.join(k2_vocab[-5:]))

'''
Write your code to visualise the term-by-document matrix
'''
# INSERT YOUR CODE HERE
fig, ax = plt.subplots(figsize=(10, 5))
ax.imshow(k2_termdoc)
ax.set_xlabel('term (vocabulary)')
ax.set_ylabel('documents (tweets)')
ax.set_title('Term-by-Document matrix from tweets collected for keyword \"{}\"'.format(keywords[1]))
# Out:
# 👍 👿 💰 😍 🤝
# Text(0.5, 1.0, 'Term-by-Document matrix from tweets collected for keyword "politics"')

# %% [markdown]
# ***Instruction 2.14***. Next, your task is to write codes in the cell below to calculate the pairwise distance matrix for tweets collected for **second** keyword. Store this distance matrix in the variable named ***k2_euclidean_distances*** and **visualise** this matrix.
#
# [**Total mark: 10**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

# compute the distance matrix for k1_termdoc using the function "compute_euclidean_distance_matrix"
# INSERT YOUR CODE HERE
k2_cdm = compute_distance_matrices(k2_termdoc)
# Visualise the distance matrix for this keyword
# Hint: use imshow() and colorbar() functions
# INSERT YOUR CODE HERE
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(k2_cdm[0],k2_cdm[1])
ax.set_xlabel('euclidean distance')
ax.set_ylabel('cosine distance')
ax.set_title('Term-by-Document matrix from tweets collected for keyword \"{}\"'.format(keywords[1]))
# Out:
# [21.6794833886788, 0.7118052168020873]
# Text(0.5, 1.0, 'Term-by-Document matrix from tweets collected for keyword "politics"')

# %% [markdown]
# **Instruction 2.15**. Similarly, your task is to write codes in the cell below to compute the term-by-document matrix and the vocabulary for tweets stored in ***k3_tweets_processed***, print out the first **5** vocabularies and visualise this term-by-document matrix.
#
# [**Total mark: 5**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your codes to compute the term-by-document matrix and the vocabulary for tweets stored 
in k3_tweets_processed
'''
# INSERT YOUR CODE HERE
k3_termdoc, k3_vocab = construct_termdoc(k3_tweets_processed)

'''
Write your code print out the first 5 vocabularies 
'''
# INSERT YOUR CODE HERE
print(' '.join(k3_vocab[-5:]))

'''
Write your code to visualise the term-by-document matrix
'''
# INSERT YOUR CODE HERE
fig, ax = plt.subplots()
ax.imshow(k3_termdoc)
ax.set_xlabel('term (vocabulary)')
ax.set_ylabel('documents (tweets)')
ax.set_title('Term-by-Document matrix from tweets collected for keyword \"{}\"'.format(keywords[2]))
# Out:
# c:\python368\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Attempting to set identical left == right == -0.5 results in singular transformations; automatically expanding.
# c:\python368\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Attempting to set identical bottom == top == -0.5 results in singular transformations; automatically expanding.
# Text(0.5, 1.0, 'Term-by-Document matrix from tweets collected for keyword "raccoon"')

# %% [markdown]
# ***Instruction 2.16***. Next, your task is to write codes in the cell below to calculate the pairwise distance matrix for tweets collected for **third** keyword. Store this distance matrix in the variable named ***k3_euclidean_distances*** and visualise this matrix.
#
# [**Total mark: 5**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

# compute the distance matrices for k1_termdoc using the function "compute_distance_matrices"
# INSERT YOUR CODE HERE
k3_cdm = compute_distance_matrices(k3_termdoc)

# Visualise the distance matrix for this keyword
# Hint: use imshow() and colorbar() functions
# INSERT YOUR CODE HERE
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(k3_cdm[0],k3_cdm[1])
ax.set_xlabel('euclidean distance')
ax.set_ylabel('cosine distance')
ax.set_title('Term-by-Document matrix from tweets collected for keyword \"{}\"'.format(keywords[2]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-76-4cacb69dd88a> in <module>
#       3 # compute the distance matrices for k1_termdoc using the function "compute_distance_matrices"
#       4 # INSERT YOUR CODE HERE
# ----> 5 k3_cdm = compute_distance_matrices(k3_termdoc)
#       6
#       7 # Visualise the distance matrix for this keyword
#
# <ipython-input-65-e87d98a96ccf> in compute_distance_matrices(termdoc)
#      10     # INSERT YOUR CODE HERE
#      11     distanceMatrices = []
# ---> 12     euclidean_distance_matrix = Euclidean_distance(termdoc[0], termdoc[1])
#      13     cosine_distance_matrix = cosine_distance(termdoc[0], termdoc[1])
#      14     distanceMatrices.append(euclidean_distance_matrix)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# ***Instruction 2.17 (HD)***. Compare the ranges of the values for cosine and Euclidean distances. Explain why the ranges are different. Think about the best example to explain why cosine distance is more convenient than Euclidean distance for text analysis.
#
# [**Total mark: 5**]

# %%
# Compare the ranges of the values for cosine and Euclidean distances. 
# Explain why the ranges are different. Explain why cosine distance 
# is more convenient than Euclidean distance for text analysis.
#
# YOU ARE REQUIRED TO INSERT YOUR COMMENT IN THIS CELL
#

# %% [markdown]
# ### Part 2C: Data Clustering
#
# Thus far in this assignment, we have collected tweets for each keyword and analysed them seperately. We have constructed the term-by-document matrix for each collection of tweets seperately. A fundemantal and common task in data science, analytics, machine learning, science and engineering is **clustering**. This is also known as unsupervised learning or exploratory data analysis as we have learned in our classes.
#
# This part of this assignment will use the Kmeans algorithm learned in our classes to cluster the **entire** colllection of tweets collected for **all** keywords. To do so, we need to compute the **distance** between **any** two pair of tweets. This requires us to compute a **joint** term-by-document matrix for all tweets.
#
# The reason that we **cannot** use the individual term-by-document matrices computed earlier (e.g.,***k1_termdoc, k2_termdoc, k3_termdoc***) for this task is because they have different dictionary sizes. Hence, tweets collected for different keywords have been represented by vectors of different dimension.
#
# The following piece of codes will help you to inspect these dimensions.

# %%
print('Dimension of the term-by-document matrix for keyword \"{}\":'.format(keywords[0]))
print('{} x {}\n'.format(k1_termdoc.shape[0],k1_termdoc.shape[1]))

print('Dimension of the term-by-document matrix for keyword \"{}\":'.format(keywords[1]))
print('{} x {}\n'.format(k2_termdoc.shape[0],k2_termdoc.shape[1]))

print('Dimension of the term-by-document matrix for keyword \"{}\":'.format(keywords[2]))
print('{} x {}\n'.format(k3_termdoc.shape[0],k3_termdoc.shape[1]))

# %% [markdown]
# **Note**. First, we need to gather all tweets together into a new variable named **all_tweets_processed** using the piece of codes below.

# %%
all_tweets_processed = k1_tweets_processed + k2_tweets_processed + k3_tweets_processed

# %% [markdown]
# **Instruction 2.18**. Your task is to write codes in the cell below to compute the term-by-document matrix and the vocabulary for all tweets stored in ***all_tweets_processed***, print out the first 5 vocabularies and visualise this term-by-document matrix.
#
# [**Total marks: 5**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your codes to compute the term-by-document matrix and the vocabulary for all tweets stored 
in all_tweets_processed
'''

all_termdoc, all_vocab = # INSERT YOUR CODE HERE

'''
Write your code print out the first 5 vocabularies 
'''
# INSERT YOUR CODE HERE

'''
Write your code to visualise the term-by-document matrix
'''
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.19**. Next, your task is to write codes in the cell below to calculate the pairwise distance matrix for all tweets collected. Store this distance matrix in the variable named ***all_euclidean_distances*** and visualise this matrix.
#
# [**Total mark: 5**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

# compute the Euclidean distance matrix using compute_euclidean_distance_matrix() function

all_euclidean_distances, all_cosine_distances = # INSERT YOUR CODE HERE

# Visualise the distance matrix for this keyword
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.20 (HD)**.
# 1. Your task is to produce a scatter plot of Euclidean vs cosine distance for all tweets. [**2 marks**]
# 2. Fit first and second order polynomials to the data in the scatter plot and overplot them. [**3 marks**]
# 3. Explain why the plotted curves do not go through the centre of the points cloud. [**4 marks**]
# 4. Which visualisation technique would be better to use here? [**1 mark**]
#
# [**Total mark: 10**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
# 1. Your task is to produce a scatter plot of Euclidean vs cosine distance for all tweets.
# INSERT YOUR CODE HERE

# 2. Fit a second order polynomial to the data in the scatter plot and overplot it. 
# INSERT YOUR CODE HERE

# %%
# YOU ARE REQUIRED TO INSERT YOUR COMMENT IN THIS CELL
#3. Explain why the plotted curves do not go through the centre of the points cloud.
#4. Which visualisation technique would be better to use here?
# INSERT YOUR COMMENTS HERE
#

# %% [markdown]
# **Note**. Next, we use Kmeans algorithm to cluster all tweets stored in term-by-document matrix ***all_termdoc***. An important requirement for the Kmeans is the specification of the number of clusters which will be specified the variable **n_clusters**.
#
# The following piece of codes will initialise a ***kmeans*** object to be used for subsequent clustering task.

# %%
'''
Initialise a kmeans object  from scikit-lean package
'''
n_clusters = 3
kmeans = KMeans(n_clusters=n_clusters, init='k-means++', n_init=5, max_iter=3000,
                verbose=True, tol=0.000001, random_state=123456)

# %% [markdown]
# **Instruction 2.21**. Your task is to use the variable ***kmeans*** to perform clustering on the data stored in the variable ***all_termdoc***.
#
# [**Total mark: 5**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

'''
Use the variable kmeans to perform clustering on the data stored in the variable all_termdoc
Hint: revise the practical session on Kmeans algorithm or check out the documentation from scikit-learn
for Kmeans algorithm.
'''
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.22**. Write your codes to print out the cluster centers.
#
# [**Total mark: 5**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your codes to print out the cluster centers.
'''
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.23 (HD)**. Explain below why visualising the clusters here is hard to do in this case.
#
# [**Total mark: 5**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR COMMENT IN THIS CELL
# Explain below why visualising the clusters here is hard to do in this case.
# INSERT YOUR COMMENT HERE

# %% [markdown]
# **Instruction 2.24 (HD)**. Nevertheless, it is possible to visualise the structure of the cluster centres - surprisingly, using bar charts. Each vector component in the cluster centre vectors corresponds to a word in the dictionary. The value (amplitude) of the vector component for each particular word in the dictionary shows the strength of presence of a word in the cluster.
# In this task, you want to:
# 1. Plot bar charts for each of the three clusters, obtained from KMeans, where each bar chart has 20 strongest words sorted by their presence strength. [**5 marks**]
# 2. Explain the bar charts from the point of view of chosen keywords, English grammar and our text preprocessing routine. [**5 marks**]
#
# [**Total mark: 10**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
# 1. Plot bar charts for each of the three clusters, obtained from KMeans, 
# where each bar chart has 20 strongest words sorted by their presence strength.
# INSERT YOUR CODE HERE

# %%
# YOU ARE REQUIRED TO INSERT YOUR COMMENT IN THIS CELL
# Explain the bar charts from the point of view of chosen keywords, English grammar 
# and our text preprocessing routine.
# INSERT YOUR COMMENT HERE
#

# %% [markdown]
# **Instruction 2.25**. Write your codes to print out the first **200** cluster labels assigned to the first 200 tweets.
#
# [**Total marks: 5**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your codes to print out the first **200** cluster labels assigned to the first 200 tweets.
'''
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.26**. Next, we would like to obtain the quality of our clustering results. Write your code to obtain the labels of tweets for each keyword and store the labels in three new variables ***k1_labels***, ***k2_labels*** and ***k3_labels***, respectively.
#
# **[Total marks: 5]**

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

'''
Write your code to obtain the labels of tweets for each keyword
and store the labels of the first keyword in ***k1_labels***, 
the labels of the second keyword in ***k2_labels*** and
the labels of the third keyword in ***k3_labels***.
'''
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.27 (D)**. We examine what is the proprotion of tweets from different keywords (or categories) appear in the **first** cluster. Remember that **0** is the label for the first cluster (**1** for the second and **2** for the third clusters). Your tasks are:
#
# 1. Write your code to obtain the list of tweet indices of each keyword that are assigned to the first cluster. **(3 marks)**
#
# 2. Plot a bar chart to visualise the number of tweets of each keyword that are assigned to the first cluster. **(2 marks)**
#
# **[Total mark: 5]**

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Write your code to obtain the list of tweet indices of each keyword that are assigned to the first cluster.
Hint: you might want to use numpy.where function.
'''
# obtain the list of tweet indices of keyword k1 that are assigned to the first cluster
# means that to find tweet indices that have label 0 in k1_labels
k1_idx_label0 = # INSERT YOUR CODE HERE

# obtain the list of tweet indices of keyword k2 that are assigned to the first cluster
# means that to find tweet indices that have label 0 in k2_labels
k2_idx_label0 = # INSERT YOUR CODE HERE

# obtain the list of tweet indices of keyword k3 that are assigned to the first cluster
# means that to find tweet indices that have label 0 in k3_labels
k3_idx_label0 = # INSERT YOUR CODE HERE

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL
'''
Plot a bar chart to visualise the number of tweets of each keyword that are assigned to the first cluster.
Hint: you need to plot a bar chart with three bars, 
each bar represents the number of tweets of each keyword that are assigned to the first cluster.
'''
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.28 (D)**. Similarly, write your codes to compute the the proprotion of tweets from different keywords (or categories) appear in the **second** cluster and plot a bar chart visualise this information.
#
# [**Total mark: 5**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

# obtain the list of tweet indices of keyword k1 that are assigned to the second cluster
# means that to find tweet indices that have label 1 in k1_labels
k1_idx_label1 = # INSERT YOUR CODE HERE

# obtain the list of tweet indices of keyword k2 that are assigned to the second cluster
# means that to find tweet indices that have label 1 in k2_labels
k2_idx_label1 = # INSERT YOUR CODE HERE

# obtain the list of tweet indices of keyword k3 that are assigned to the second cluster
# means that to find tweet indices that have label 1 in k3_labels
k3_idx_label1 = # INSERT YOUR CODE HERE

# Plot a bar chart to visualise the number of tweets of each keyword that are assigned to the second cluster
# INSERT YOUR CODE HERE

# %% [markdown]
# **Instruction 2.29 (D)**. Similarly, write your codes to compute the the proprotion of tweets from different keywords (or categories) appear in the **third** cluster and plot a bar chart visualise this information.
#
# [**Total mark: 5**]

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODE IN THIS CELL

# obtain the list of tweet indices of keyword k1 that are assigned to the third cluster
# means that to find tweet indices that have label 2 in k1_labels
k1_idx_label2 = # INSERT YOUR CODE HERE

# obtain the list of tweet indices of keyword k2 that are assigned to the third cluster
# means that to find tweet indices that have label 2 in k2_labels
k2_idx_label2 = # INSERT YOUR CODE HERE

# obtain the list of tweet indices of keyword k3 that are assigned to the third cluster
# means that to find tweet indices that have label 2 in k3_labels
k3_idx_label2 = # INSERT YOUR CODE HERE

# Plot a bar chart to visualise the number of tweets of each keyword that are assigned to the third cluster
# INSERT YOUR CODE HERE

# %% [markdown]
# ### END OF ASSIGNMENT 2 NOTEBOOK
#
# ----
